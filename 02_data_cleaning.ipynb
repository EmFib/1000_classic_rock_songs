# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm

# for loading data
import pickle

# for text cleaning
import re
import string

# tokenizing
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Reading in Data

# %% [markdown]
# _Something to try later_

# %%
# bob_pickle_file = open("./lyrics/bob_dylan.txt", "rb")
# objects = []
# while True:
#     try:
#         objects.append(pickle.load(bob_pickle_file))
#     except EOFError:
#         break
# pickle_file.close()

# %% [markdown]
# _Practicing with Led Zeppelin_

# %%
with open("lyrics/test_cases/led zeppelin.pkl", "rb") as file: 
    led = pickle.load(file)

# %%
led
# Out:
# "There's a lady who's sure all that glitters is gold\nAnd she's buying a stairway to Heaven\nWhen she gets there she knows, if the stores are all closed\nWith a word she can get what she came for\nOoh, ooh, and she's buying a stairway to Heaven\nThere's a sign on the wall, but she wants to be sure\n'Cause you know sometimes words have two meanings\nIn a tree by the brook, there's a songbird who sings\nSometimes all of our thoughts are misgiven\nOoh, makes me wonder\nOoh, makes me wonder\nThere's a feeling I get when I look to the west\nAnd my spirit is crying for leaving\nIn my thoughts I have seen rings of smoke through the trees\nAnd the voices of those who stand looking\nOoh, it makes me wonder\nOoh, really makes me wonder\nAnd it's whispered that soon if we all call the tune\nThen the piper will lead us to reason\nAnd a new day will dawn for those who stand long\nAnd the forests will echo with laughter\nOh-oh-oh-oh-woahhh\nIf there's a bustle in your hedgerow, don't be alarmed, n
# ...

# %% [markdown]
# ### **Reading in 11 primary musicians at once**

# %% [markdown]
# _Note about musician names: After pickling the code in the 01_data_collection notebook, I changed the names of the '.pkl' and '.txt' files to have a hyphen between the first name and the last name of the musican. I will used these hypenated names going forward as the name becomes the key for the musician in the data dictionary and I don't want the keys to have white space._

# %%
#musician names 

musicians = ['bob_dylan', 'neil_young', 'willie_nelson', 'the_band', 'john_prine', 'leonard_cohen', 
             'janis_joplin', 'linda_ronstadt', 'mark_knopfler', 'david_bowie', 'stevie_nicks']

len(musicians)
# Out:
# 11

# %%
# Load pickled files

# THIS DOESN'T WORK 

data = {}

for i, c in enumerate(musicians):
    with open("lyrics/" + c + ".pkl", "rb") as file: 
        data[c] = pickle.load(file)

# %%
# Double check to make sure data has been loaded properly 

data.keys()
# Out:
# dict_keys(['bob_dylan', 'neil_young', 'willie_nelson', 'the_band', 'john_prine', 'leonard_cohen', 'janis_joplin', 'linda_ronstadt', 'mark_knopfler', 'david_bowie', 'stevie_nicks'])

# %%
# another check 

data['willie_nelson']
# Out:
# 'Cruel, cruel world, must I go on?\nCruel, cruel world, I\'m moving on\nI\'ve been living too fast\nAnd I\'ve been living too wrong\nCruel, cruel world, I\'m gone\nThis big ol\' world sure got me running \'round\nI heard a voice that said, "Just settle down"\nAnd with the moonlight as my guide\nAnd with this feeling deep inside\nI know now that I am homeward bound\nCruel, cruel world, must I go on?\nCruel, cruel world, I\'m moving on\nI\'ve been living too fast\nAnd I\'ve been living too wrong\nCruel, cruel world, I\'m gone\nDesert roads, desert plains\nI have seen so much pain\nNow I see into the eyes of a girl\nNo more, no more, cruel world\nCruel, cruel world, must I go on?\nCruel, cruel world, I\'m moving on\nI\'ve been living too fast\nAnd I\'ve been living too wrong\nCruel, cruel world, I\'m gone\nDusty trail, saw vapor light\nWas it a mirage? I don\'t know, but it seemed right\nI felt mission, I felt trust\nI knew then that I must\nMust go to her from this cruel world\nCruel, 
# ...

# %%
data['bob_dylan']
# Out:
# '\'Twas a dark day in Dallas, November \'63\nA day that will live on in infamy\nPresident\u2005Kennedy\u2005was a-ridin\' high\nGood\u2005day to be livin\' and a\u2005good day to die\nBeing led to the slaughter like a sacrificial lamb\nHe said, "Wait a minute, boys, you know who I am?"\n"Of course we do, we know who you are"\nThen they blew off his head while he was still in the car\nShot down like a dog in broad daylight\nWas a matter of timing and the timing was right\nYou got unpaid debts, we\'ve come to collect\nWe\'re gonna kill you with hatred, without any respect\nWe\'ll mock you and shock you and we\'ll grin in your face\nWe\'ve already got someone here to take your place\nThe day they blew out the brains of the king\nThousands were watching, no one saw a thing\nIt happened so quickly, so quick, by surprise\nRight there in front of everyone\'s eyes\nGreatest magic trick ever under the sun\nPerfectly executed, skillfully done\nWolfman, oh Wolfman, oh Wolfman, howl\nRub-a-dub-d
# ...

# %%
len(data['bob_dylan'])
# Out:
# 7263

# %%
len(data['willie_nelson'])
# Out:
# 1282

# %%
len(data['neil_young'])
# Out:
# 940

# %%
len(data['janis_joplin'])
# Out:
# 1823

# %%
# creating single objects called "bob" to expriment 

with open('lyrics/bob_dylan.pkl', 'rb') as f:
    bob = pickle.load(f)

# %%
bob
# Out:
# '\'Twas a dark day in Dallas, November \'63\nA day that will live on in infamy\nPresident\u2005Kennedy\u2005was a-ridin\' high\nGood\u2005day to be livin\' and a\u2005good day to die\nBeing led to the slaughter like a sacrificial lamb\nHe said, "Wait a minute, boys, you know who I am?"\n"Of course we do, we know who you are"\nThen they blew off his head while he was still in the car\nShot down like a dog in broad daylight\nWas a matter of timing and the timing was right\nYou got unpaid debts, we\'ve come to collect\nWe\'re gonna kill you with hatred, without any respect\nWe\'ll mock you and shock you and we\'ll grin in your face\nWe\'ve already got someone here to take your place\nThe day they blew out the brains of the king\nThousands were watching, no one saw a thing\nIt happened so quickly, so quick, by surprise\nRight there in front of everyone\'s eyes\nGreatest magic trick ever under the sun\nPerfectly executed, skillfully done\nWolfman, oh Wolfman, oh Wolfman, howl\nRub-a-dub-d
# ...

# %%
with open('lyrics/johnny_cash.pkl', 'rb') as f:
    johnny = pickle.load(f)

# %%
johnny
# Out:
# 'Love is a burning thing\nAnd it makes a fiery ring\nBound by wild desire\nI fell in to a ring of fire\nI fell into a burning ring of fire\nI went down, down, down\nAnd the flames went higher\nAnd it burns, burns, burns\nThe ring of fire\nThe ring of fire\nI fell into a burning ring of fire\nI went down, down, down\nAnd the flames went higher\nAnd it burns, burns, burns\nThe ring of fire\nThe ring of fire\nThe taste of love is sweet\nWhen hearts like ours meet\nI fell for you like a child\nOh, but the fire went wild\nI fell in to a burning ring of fire\nI went down, down, down\nAnd the flames went higher\nAnd it burns, burns, burns\nThe ring of fire\nThe ring of fire\nI fell into a burning ring of fire\nI went down, down, down\nAnd the flames went higher\nAnd it burns, burns, burns\nThe ring of fire\nThe ring of fire\nAnd it burns, burns, burns\nThe ring of fire\nThe ring of fire\nThe ring of fire\nThe ring of fire\nThe ring of fire\nThe ring...'

# %%
len(johnny)
# Out:
# 920

# %%
with open('lyrics/johnny cash.pkl', 'rb') as f:
    johnny2 = pickle.load(f)

# %%
johnny2
# Out:
# "The other night dear, as I lay sleeping\nI dreamed I held you in my arms\nWhen I awoke, dear, I was mistaken\nSo I bowed my head and I cried\nYou are my sunshine, my only sunshine\nYou make me happy when skies are gray\nYou'll never know, dear, how much I love you\nPlease don't take my sunshine away\nI've always loved you and made you happy\nAnd nothing else could come between\nBut now you've left me to love another\nYou have shattered all of my dreams\nYou are my sunshine, my only sunshine\nYou make me happy when skies are gray\nYou'll never know, dear, how much I love you\nPlease don't take my sunshine away"

# %%
len(johnny2)
# Out:
# 601

# %%
with open('lyrics/johnny cash.pkl', 'rb') as f:
    johnny3 = pickle.load(f)

# %%
johnny3
# Out:
# "The other night dear, as I lay sleeping\nI dreamed I held you in my arms\nWhen I awoke, dear, I was mistaken\nSo I bowed my head and I cried\nYou are my sunshine, my only sunshine\nYou make me happy when skies are gray\nYou'll never know, dear, how much I love you\nPlease don't take my sunshine away\nI've always loved you and made you happy\nAnd nothing else could come between\nBut now you've left me to love another\nYou have shattered all of my dreams\nYou are my sunshine, my only sunshine\nYou make me happy when skies are gray\nYou'll never know, dear, how much I love you\nPlease don't take my sunshine away"

# %%
bob_pickle_file = open("./lyrics/bob_dylan.pkl", "rb")
objects = []
while True:
    try:
        objects.append(pickle.load(bob_pickle_file))
        objects.append(' ')
    except EOFError:
        break
bob_pickle_file.close()

# %%
len(objects)
# Out:
# 200

# %%
objects
# Out:
# ['\'Twas a dark day in Dallas, November \'63\nA day that will live on in infamy\nPresident\u2005Kennedy\u2005was a-ridin\' high\nGood\u2005day to be livin\' and a\u2005good day to die\nBeing led to the slaughter like a sacrificial lamb\nHe said, "Wait a minute, boys, you know who I am?"\n"Of course we do, we know who you are"\nThen they blew off his head while he was still in the car\nShot down like a dog in broad daylight\nWas a matter of timing and the timing was right\nYou got unpaid debts, we\'ve come to collect\nWe\'re gonna kill you with hatred, without any respect\nWe\'ll mock you and shock you and we\'ll grin in your face\nWe\'ve already got someone here to take your place\nThe day they blew out the brains of the king\nThousands were watching, no one saw a thing\nIt happened so quickly, so quick, by surprise\nRight there in front of everyone\'s eyes\nGreatest magic trick ever under the sun\nPerfectly executed, skillfully done\nWolfman, oh Wolfman, oh Wolfman, howl\nRub-a-dub-
# ...

# %%
# trying this

with open('lyrics/bob_dylan.pkl', 'rb') as file:
    try:
        while True:
            bob2=pickle.load(file)
            print(bob2)
    except EOFError:
        print('End of File')
# Out:
# 'Twas a dark day in Dallas, November '63
# A day that will live on in infamy
# President Kennedy was a-ridin' high
# Good day to be livin' and a good day to die
# Being led to the slaughter like a sacrificial lamb
# He said, "Wait a minute, boys, you know who I am?"
# "Of course we do, we know who you are"
# Then they blew off his head while he was still in the car
# Shot down like a dog in broad daylight
# Was a matter of timing and the timing was right
# You got unpaid debts, we've come to collect
# We're gonna kill you with hatred, without any respect
# We'll mock you and shock you and we'll grin in your face
# We've already got someone here to take your place
# The day they blew out the brains of the king
# Thousands were watching, no one saw a thing
# It happened so quickly, so quick, by surprise
# Right there in front of everyone's eyes
# Greatest magic trick ever under the sun
# Perfectly executed, skillfully done
# Wolfman, oh Wolfman, oh Wolfman, howl
# ...

# %%
bob2
# Out:
# "Standing on the waters casting your bread\nWhile the eyes of the idol with the iron head are glowing\nDistant ships sailing into the mist\nYou were born with a snake in both of your fists while a hurricane was blowing\nFreedom just around the corner for you\nBut with the truth so far off, what good will it do?\nJokerman dance to the nightingale tune\nBird fly high by the light of the moon\nOh, oh, oh, Jokerman\nSo swiftly the sun sets in the sky\nYou rise up and say goodbye to no one\nFools rush in where angels fear to tread\nBoth of their futures, so full of dread, you don't show one\nShedding off one more layer of skin\nKeeping one step ahead of the persecutor within\nJokerman dance to the nightingale tune\nBird fly high by the light of the moon\nOh, oh, oh, Jokerman\nYou're a man of the mountains, you can walk on the clouds\nManipulator of crowds, you're a dream twister\nYou're going to Sodom and Gomorrah\nBut what do you care? Ain't nobody there would want to marry your sister\n
# ...

# %%
len(bob2)
# Out:
# 2469

# %% [markdown]
# # LOADING THE RIGHT WAY

# %%
# bob_pickle_file = open("./lyrics/bob_dylan.pkl", "rb")
# objects = []
# while True:
#     try:
#         objects.append(pickle.load(bob_pickle_file))
#     except EOFError:
#         break
# bob_pickle_file.close()

# %%
# Load pickled files

data = {}

for i, c in enumerate(musicians):
    file = open("./lyrics/" + c + ".pkl", "rb")
    data[c] = []
    while True:
        try:
            data[c].append(pickle.load(file))
        except EOFError:
            break
    file.close()

# %%
# Double check to make sure data has been loaded properly 

data.keys()
# Out:
# dict_keys(['bob_dylan', 'neil_young', 'willie_nelson', 'the_band', 'john_prine', 'leonard_cohen', 'janis_joplin', 'linda_ronstadt', 'mark_knopfler', 'david_bowie', 'stevie_nicks'])

# %%
# More checks 
data['bob_dylan']
# Out:
# ['\'Twas a dark day in Dallas, November \'63\nA day that will live on in infamy\nPresident\u2005Kennedy\u2005was a-ridin\' high\nGood\u2005day to be livin\' and a\u2005good day to die\nBeing led to the slaughter like a sacrificial lamb\nHe said, "Wait a minute, boys, you know who I am?"\n"Of course we do, we know who you are"\nThen they blew off his head while he was still in the car\nShot down like a dog in broad daylight\nWas a matter of timing and the timing was right\nYou got unpaid debts, we\'ve come to collect\nWe\'re gonna kill you with hatred, without any respect\nWe\'ll mock you and shock you and we\'ll grin in your face\nWe\'ve already got someone here to take your place\nThe day they blew out the brains of the king\nThousands were watching, no one saw a thing\nIt happened so quickly, so quick, by surprise\nRight there in front of everyone\'s eyes\nGreatest magic trick ever under the sun\nPerfectly executed, skillfully done\nWolfman, oh Wolfman, oh Wolfman, howl\nRub-a-dub-
# ...

# %%
data['willie_nelson']
# Out:
# ['Cruel, cruel world, must I go on?\nCruel, cruel world, I\'m moving on\nI\'ve been living too fast\nAnd I\'ve been living too wrong\nCruel, cruel world, I\'m gone\nThis big ol\' world sure got me running \'round\nI heard a voice that said, "Just settle down"\nAnd with the moonlight as my guide\nAnd with this feeling deep inside\nI know now that I am homeward bound\nCruel, cruel world, must I go on?\nCruel, cruel world, I\'m moving on\nI\'ve been living too fast\nAnd I\'ve been living too wrong\nCruel, cruel world, I\'m gone\nDesert roads, desert plains\nI have seen so much pain\nNow I see into the eyes of a girl\nNo more, no more, cruel world\nCruel, cruel world, must I go on?\nCruel, cruel world, I\'m moving on\nI\'ve been living too fast\nAnd I\'ve been living too wrong\nCruel, cruel world, I\'m gone\nDusty trail, saw vapor light\nWas it a mirage? I don\'t know, but it seemed right\nI felt mission, I felt trust\nI knew then that I must\nMust go to her from this cruel world\nCruel,
# ...

# %%
for v in data.values():
    print(len(v))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
len(data.keys())
# Out:
# 11

# %%
type(data['bob_dylan'])
# Out:
# list

# %%
type(data['bob_dylan'][1])
# Out:
# str

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# **Data cleaning steps on all text:**
# * Make text all lower case
# * Remove punctuation
# * Remove numerical values
# * Remove common non-sensical text (/n)
# * Tokenize text
# * Remove stop words
#
# **More data cleaning after tokenization:**
# * Stemming / lemmatization
# * Parts of speech tagging
# * Create bi-grams or tri-grams
# * Deal with typos
# * And more...

# %%
# checking out data once more 

next(iter(data.keys()))
# Out:
# 'bob_dylan'

# %%
# Notice that our dictionary is currently in key: musician, value: list with each entry being lyrics for one song 
next(iter(data.values()))
# Out:
# ['\'Twas a dark day in Dallas, November \'63\nA day that will live on in infamy\nPresident\u2005Kennedy\u2005was a-ridin\' high\nGood\u2005day to be livin\' and a\u2005good day to die\nBeing led to the slaughter like a sacrificial lamb\nHe said, "Wait a minute, boys, you know who I am?"\n"Of course we do, we know who you are"\nThen they blew off his head while he was still in the car\nShot down like a dog in broad daylight\nWas a matter of timing and the timing was right\nYou got unpaid debts, we\'ve come to collect\nWe\'re gonna kill you with hatred, without any respect\nWe\'ll mock you and shock you and we\'ll grin in your face\nWe\'ve already got someone here to take your place\nThe day they blew out the brains of the king\nThousands were watching, no one saw a thing\nIt happened so quickly, so quick, by surprise\nRight there in front of everyone\'s eyes\nGreatest magic trick ever under the sun\nPerfectly executed, skillfully done\nWolfman, oh Wolfman, oh Wolfman, howl\nRub-a-dub-
# ...

# %%
# changing this to key: musician, value: string format 

def combine_text(list_of_text):
    '''Takes a list of text and combines the entries into one large chunk of text'''
    combined_text = ' '.join(list_of_text)
    return combined_text

# %%
# Combining list of lyrics 

data_combined = {key: [combine_text(value)] for (key, value) in data.items()}

# %%
# checking that this worked 
len(data_combined['bob_dylan'])
# Out:
# 1

# %%
next(iter(data_combined.values()))
# Out:
# ['\'Twas a dark day in Dallas, November \'63\nA day that will live on in infamy\nPresident\u2005Kennedy\u2005was a-ridin\' high\nGood\u2005day to be livin\' and a\u2005good day to die\nBeing led to the slaughter like a sacrificial lamb\nHe said, "Wait a minute, boys, you know who I am?"\n"Of course we do, we know who you are"\nThen they blew off his head while he was still in the car\nShot down like a dog in broad daylight\nWas a matter of timing and the timing was right\nYou got unpaid debts, we\'ve come to collect\nWe\'re gonna kill you with hatred, without any respect\nWe\'ll mock you and shock you and we\'ll grin in your face\nWe\'ve already got someone here to take your place\nThe day they blew out the brains of the king\nThousands were watching, no one saw a thing\nIt happened so quickly, so quick, by surprise\nRight there in front of everyone\'s eyes\nGreatest magic trick ever under the sun\nPerfectly executed, skillfully done\nWolfman, oh Wolfman, oh Wolfman, howl\nRub-a-dub-
# ...

# %%
data_combined['bob_dylan']
# Out:
# ['\'Twas a dark day in Dallas, November \'63\nA day that will live on in infamy\nPresident\u2005Kennedy\u2005was a-ridin\' high\nGood\u2005day to be livin\' and a\u2005good day to die\nBeing led to the slaughter like a sacrificial lamb\nHe said, "Wait a minute, boys, you know who I am?"\n"Of course we do, we know who you are"\nThen they blew off his head while he was still in the car\nShot down like a dog in broad daylight\nWas a matter of timing and the timing was right\nYou got unpaid debts, we\'ve come to collect\nWe\'re gonna kill you with hatred, without any respect\nWe\'ll mock you and shock you and we\'ll grin in your face\nWe\'ve already got someone here to take your place\nThe day they blew out the brains of the king\nThousands were watching, no one saw a thing\nIt happened so quickly, so quick, by surprise\nRight there in front of everyone\'s eyes\nGreatest magic trick ever under the sun\nPerfectly executed, skillfully done\nWolfman, oh Wolfman, oh Wolfman, howl\nRub-a-dub-
# ...

# %%
# changing dataframe properties to allow for longer column width
pd.set_option('max_colwidth', 150)

# %%
# Putting dictionary into Pandas dataframe 
data_df = pd.DataFrame.from_dict(data_combined).transpose()
data_df.columns = ['lyrics']
data_df = data_df.sort_index()
data_df
# Out:
#                                                                                                                                                                lyrics
# bob_dylan       'Twas a dark day in Dallas, November '63\nA day that will live on in infamy\nPresident Kennedy was a-ridin' high\nGood day to be livin' and a good...
# david_bowie     Mmm num ba de\nDum bum ba be\nDoo buh dum ba beh beh\nPressure pushing down on me\nPressing down on you, no man ask for\nUnder pressure that burns...
# janis_joplin    Busted flat in Baton Rouge, waiting for a train\nWhen I was feeling nearly faded as my jeans\nBobby thumbed a diesel down, just before it rained\n...
# john_prine      She don't like her eggs all runny\nShe thinks crossin' her legs is funny\nShe looks down her nose at money\nShe gets it on like the Easter Bunny\n...
# ...

# %%
# looking at John Prine lyrics 
data_df['lyrics'].loc['john_prine']
# Out:
# 'She don\'t like her eggs all runny\nShe thinks crossin\' her legs is funny\nShe looks down her nose at money\nShe gets it on like the Easter Bunny\nShe\'s my baby, I\'m her honey\nI\'m never gonna let her go\nHe ain\'t got laid in a month of Sundays\nI caught him once and he was sniffin\' my undies\nHe ain\'t too sharp, but he gets things done\nDrinks his beer like it\'s oxygen\nHe\'s my baby and I\'m his honey\nI\'m never gonna let him go\nIn spite of ourselves, we\'ll end up a-sittin\' on a rainbow\nAgainst all odds, honey, we\'re the big door prize\nWe\'re gonna spite our noses right off of our faces\nThere won\'t be nothin\' but big old hearts dancin\' in our eyes\nShe thinks all my jokes are corny\nConvict movies make her horny\nShe likes ketchup on her scrambled eggs\nSwears like a sailor when she shaves her legs\nShe takes a lickin\' and keeps on tickin\'\nI\'m never gonna let her go\nHe\'s got more balls than a big brass monkey\nHe\'s a whacked-out weirdo and a lovebug junki
# ...

# %%
# Apply a first round of text cleaning techniques

def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

round1 = lambda x: clean_text_round1(x)

# %%
# updated text 

data_clean = pd.DataFrame(data_df['lyrics'].apply(round1))
data_clean
# Out:
#                                                                                                                                                                lyrics
# bob_dylan       twas a dark day in dallas november \na day that will live on in infamy\npresident kennedy was aridin high\ngood day to be livin and a good day to ...
# david_bowie     mmm num ba de\ndum bum ba be\ndoo buh dum ba beh beh\npressure pushing down on me\npressing down on you no man ask for\nunder pressure that burns ...
# janis_joplin    busted flat in baton rouge waiting for a train\nwhen i was feeling nearly faded as my jeans\nbobby thumbed a diesel down just before it rained\nan...
# john_prine      she dont like her eggs all runny\nshe thinks crossin her legs is funny\nshe looks down her nose at money\nshe gets it on like the easter bunny\nsh...
# ...

# %%
# second round of text cleaning 

def clean_text_round2(text):
    '''Get rid of some additional punctuation and other non relevant text that was missed the first time.'''
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '  ', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
# updated text - round 2 

data_clean = pd.DataFrame(data_clean['lyrics'].apply(round2))
data_clean
# Out:
#                                                                                                                                                                lyrics
# bob_dylan       twas a dark day in dallas november   a day that will live on in infamy  president kennedy was aridin high  good day to be livin and a good day to ...
# david_bowie     mmm num ba de  dum bum ba be  doo buh dum ba beh beh  pressure pushing down on me  pressing down on you no man ask for  under pressure that burns ...
# janis_joplin    busted flat in baton rouge waiting for a train  when i was feeling nearly faded as my jeans  bobby thumbed a diesel down just before it rained  an...
# john_prine      she dont like her eggs all runny  she thinks crossin her legs is funny  she looks down her nose at money  she gets it on like the easter bunny  sh...
# ...

# %% [markdown]
# ## Pickling Corpus and Cleaned DataFrame

# %%
data_df.to_pickle("corpus.pkl")

# %%
data_clean.to_pickle("data_clean.pkl")

# %% [markdown]
# ## Document-Term Matrix

# %% [markdown]
# Using scikit-learn's `CountVectorizer` to tokenize the text and remove stop words.

# %%
# creating a document-term matrix 

cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(data_clean['lyrics'])
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_dtm.index = data_clean.index
data_dtm
# Out:
#                 aah  aahh  aahhha  aaj  aasra  abandon  abandonarme  \
# bob_dylan         0     0       0    0      0        0            0
# david_bowie       0     0       0    0      0        0            0
# janis_joplin      3     1       2    0      0        0            0
# john_prine        1     0       0    0      0        0            0
# leonard_cohen     0     0       0    0      0        1            0
# linda_ronstadt    0     0       0    0      0        0            1
# mark_knopfler     0     0       0    0      0        0            0
# neil_young        0     0       0    0      0        0            0
# stevie_nicks      1     0       0    0      0        0            0
# the_band          0     0       0    1      1        0            0
# willie_nelson     0     0       0    0      0        0            0
#
#                 abandoned  abangin  abar  ...  çok  çözebilirsin  étaient  \
# bob_dylan               2        0     0  ...    0             0        0
# ...

# %% [markdown]
# ## Pickling document-term matrix and CountVectorizer object

# %%
data_dtm.to_pickle("dtm.pkl")

# %%
pickle.dump(cv, open("cv.pkl", "wb"))
